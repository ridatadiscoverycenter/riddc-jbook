# %% [markdown]
# ***We recommend working with this notebook on Google Colab***
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ridatadiscoverycenter/riddc-jbook/blob/main/riddc/notebooks/fox-kemper/Volume_viewer_converter.ipynb)
#
# # Visualize OSOM data using the OSOM 3D volume viewer
#
#
# <img src="https://github.com/ridatadiscoverycenter/riddc-jbook/raw/main/riddc/notebooks/fox-kemper/images/volume-viewer-2.png" >
#
# The following example goes through how to export OSOM datasets and visualize them in 3D using the Volume Viewer application.
# **NOTE: These scripts create a large amount of data. We recommend using your Google Drive to save them.**
#
# You can use the Volume Viewer either from you computer or using Brown's Oscar HPC.
#
# ## 1. Get the Volume Viewer Application
#
# You can either dowload the Volume Viewer and work locally (option a), or load it as a module in Oscar and work there (option b, recommended).
#
# ### a. Download Volume Viewer
#
# If you wish to work locally, you can find the latest version of the Volume Viewer application on [this link](https://github.com/brown-ccv/VR-Volumeviewer/releases). Download the file `volume-viewer.zip` and unzip it on your local machine.
#
#
# ### b. Using Oscar HPC
#
# Log in to Oscar using [OOD](https://ood.ccv.brown.edu/) and open the desktop application with at least 1 GPU.
#
# <img src="https://raw.githubusercontent.com/ridatadiscoverycenter/riddc-jbook/main/riddc/notebooks/fox-kemper/images/ood-desktop-session.png" >
#
# Go to the terminal inside the virtual desktop and type the following commands:
#
# `module load volumeviewer/2.0`
# `module load gcc/10.2`
# `VR-Volumeviewer`
#
# ## 2. Mount Google Drive
#
# Execute the rest of the commands below directly in this notebook to connect to your Google Drive
#
# **NOTE: The following command will open a pop-up window requesting access to your Google Drive file system**

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting google.colab
#   Downloading google-colab-1.0.0.tar.gz (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting google-auth~=1.4.0
#   Downloading google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 2.2 MB/s eta 0:00:00
# Collecting ipykernel~=4.6.0
#   Downloading ipykernel-4.6.1-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.5/104.5 kB 3.8 MB/s eta 0:00:00
# Collecting ipython~=5.5.0
#   Downloading ipython-5.5.0-py3-none-any.whl (758 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 kB 13.6 MB/s eta 0:00:0000:01
# Collecting notebook~=5.2.0
#   Downloading notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 25.3 MB/s eta 0:00:0000:0100:01
# Collecting six~=1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas~=0.24.0
#   Downloading pandas-0.24.2.tar.gz (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 26.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting portpicker~=1.2.0
#   Downloading portpicker-1.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting requests~=2.21.0
#   Downloading requests-2.21.0-py2.py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 2.1 MB/s eta 0:00:00
# Collecting tornado~=4.5.0
#   Downloading tornado-4.5.3.tar.gz (484 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.2/484.2 kB 12.2 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: rsa>=3.1.4 in /opt/homebrew/lib/python3.9/site-packages (from google-auth~=1.4.0->google.colab) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.9/site-packages (from google-auth~=1.4.0->google.colab) (0.2.8)
# Requirement already satisfied: cachetools>=2.0.0 in /opt/homebrew/lib/python3.9/site-packages (from google-auth~=1.4.0->google.colab) (5.3.0)
# Requirement already satisfied: traitlets>=4.1.0 in /opt/homebrew/lib/python3.9/site-packages (from ipykernel~=4.6.0->google.colab) (5.3.0)
# Requirement already satisfied: jupyter-client in /opt/homebrew/lib/python3.9/site-packages (from ipykernel~=4.6.0->google.colab) (7.3.4)
# Requirement already satisfied: appnope in /opt/homebrew/lib/python3.9/site-packages (from ipython~=5.5.0->google.colab) (0.1.3)
# Requirement already satisfied: decorator in /opt/homebrew/lib/python3.9/site-packages (from ipython~=5.5.0->google.colab) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in /opt/homebrew/lib/python3.9/site-packages (from ipython~=5.5.0->google.colab) (65.6.3)
# Requirement already satisfied: pickleshare in /opt/homebrew/lib/python3.9/site-packages (from ipython~=5.5.0->google.colab) (0.7.5)
# Requirement already satisfied: pexpect in /opt/homebrew/lib/python3.9/site-packages (from ipython~=5.5.0->google.colab) (4.8.0)
# Requirement already satisfied: pygments in /opt/homebrew/lib/python3.9/site-packages (from ipython~=5.5.0->google.colab) (2.13.0)
# Collecting simplegeneric>0.8
#   Downloading simplegeneric-0.8.1.zip (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting prompt-toolkit<2.0.0,>=1.0.4
#   Downloading prompt_toolkit-1.0.18-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.4/245.4 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: nbformat in /opt/homebrew/lib/python3.9/site-packages (from notebook~=5.2.0->google.colab) (5.4.0)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.9/site-packages (from notebook~=5.2.0->google.colab) (3.1.2)
# Requirement already satisfied: terminado>=0.3.3 in /opt/homebrew/lib/python3.9/site-packages (from notebook~=5.2.0->google.colab) (0.15.0)
# Requirement already satisfied: nbconvert in /opt/homebrew/lib/python3.9/site-packages (from notebook~=5.2.0->google.colab) (7.2.5)
# Requirement already satisfied: ipython-genutils in /opt/homebrew/lib/python3.9/site-packages (from notebook~=5.2.0->google.colab) (0.2.0)
# Requirement already satisfied: jupyter-core in /opt/homebrew/lib/python3.9/site-packages (from notebook~=5.2.0->google.colab) (4.11.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/homebrew/lib/python3.9/site-packages (from pandas~=0.24.0->google.colab) (2.8.2)
# Requirement already satisfied: pytz>=2011k in /opt/homebrew/lib/python3.9/site-packages (from pandas~=0.24.0->google.colab) (2022.5)
# Requirement already satisfied: numpy>=1.12.0 in /opt/homebrew/lib/python3.9/site-packages (from pandas~=0.24.0->google.colab) (1.23.2)
# Collecting chardet<3.1.0,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 4.9 MB/s eta 0:00:00
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 2.1 MB/s eta 0:00:00
# Collecting urllib3<1.25,>=1.21.1
#   Downloading urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.8/118.8 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tdivoll/Library/Python/3.9/lib/python/site-packages (from requests~=2.21.0->google.colab) (2022.6.15)
# Requirement already satisfied: wcwidth in /opt/homebrew/lib/python3.9/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython~=5.5.0->google.colab) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth~=1.4.0->google.colab) (0.4.8)
# Requirement already satisfied: ptyprocess in /opt/homebrew/lib/python3.9/site-packages (from terminado>=0.3.3->notebook~=5.2.0->google.colab) (0.7.0)
# Collecting terminado>=0.3.3
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
#   Using cached terminado-0.17.0-py3-none-any.whl (16 kB)
#   Using cached terminado-0.16.0-py3-none-any.whl (16 kB)
#   Downloading terminado-0.13.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.9/site-packages (from jinja2->notebook~=5.2.0->google.colab) (2.1.1)
# Requirement already satisfied: pyzmq>=23.0 in /opt/homebrew/lib/python3.9/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (23.2.1)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /opt/homebrew/lib/python3.9/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (1.5.5)
# Requirement already satisfied: entrypoints in /opt/homebrew/lib/python3.9/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (0.4)
# Collecting jupyter-client
#   Using cached jupyter_client-8.0.2-py3-none-any.whl (103 kB)
# Collecting jupyter-core
#   Using cached jupyter_core-5.2.0-py3-none-any.whl (94 kB)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /opt/homebrew/lib/python3.9/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (4.12.0)
# Collecting jupyter-client
#   Downloading jupyter_client-8.0.1-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.7 MB/s eta 0:00:00
#   Downloading jupyter_client-8.0.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.8 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 4.9 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.8-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 5.2 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.7-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 5.1 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.6-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 5.1 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.5-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 5.1 MB/s eta 0:00:00
#   Using cached jupyter_client-7.4.4-py3-none-any.whl (132 kB)
#   Downloading jupyter_client-7.4.3-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 5.0 MB/s eta 0:00:00
#   Using cached jupyter_client-7.4.2-py3-none-any.whl (132 kB)
#   Downloading jupyter_client-7.4.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 4.3 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 5.2 MB/s eta 0:00:00
#   Using cached jupyter_client-7.3.5-py3-none-any.whl (132 kB)
#   Downloading jupyter_client-7.3.3-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 4.9 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.2-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.9/131.9 kB 4.7 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.1-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 4.7 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.9/130.9 kB 2.7 MB/s eta 0:00:00a 0:00:01
#   Downloading jupyter_client-7.2.2-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.6/130.6 kB 4.8 MB/s eta 0:00:00
#   Downloading jupyter_client-7.2.1-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.4/130.4 kB 4.5 MB/s eta 0:00:00
#   Downloading jupyter_client-7.2.0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 4.9 MB/s eta 0:00:00
#   Downloading jupyter_client-7.1.2-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/lib/python3.9/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/lib/python3.9/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (4.11.1)
# Requirement already satisfied: bleach in /opt/homebrew/lib/python3.9/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (5.0.1)
# Requirement already satisfied: tinycss2 in /opt/homebrew/lib/python3.9/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (1.1.1)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.9/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (21.3)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/homebrew/lib/python3.9/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (2.0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/lib/python3.9/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (1.5.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/lib/python3.9/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/homebrew/lib/python3.9/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.5.13)
# Requirement already satisfied: jsonschema>=2.6 in /opt/homebrew/lib/python3.9/site-packages (from nbformat->notebook~=5.2.0->google.colab) (3.2.0)
# Requirement already satisfied: fastjsonschema in /opt/homebrew/lib/python3.9/site-packages (from nbformat->notebook~=5.2.0->google.colab) (2.16.1)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client->ipykernel~=4.6.0->google.colab) (3.8.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/homebrew/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook~=5.2.0->google.colab) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/homebrew/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook~=5.2.0->google.colab) (21.4.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->notebook~=5.2.0->google.colab) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/homebrew/lib/python3.9/site-packages (from bleach->nbconvert->notebook~=5.2.0->google.colab) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/lib/python3.9/site-packages (from packaging->nbconvert->notebook~=5.2.0->google.colab) (3.0.9)
# Building wheels for collected packages: google.colab, pandas, portpicker, tornado, simplegeneric
#   Building wheel for google.colab (setup.py) ... done
#   Created wheel for google.colab: filename=google_colab-1.0.0-py2.py3-none-any.whl size=102272 sha256=1066439499ce1af3fedab1f101430f8f127446c4daa7c4ab1960825cc698b35a
#   Stored in directory: /Users/tdivoll/Library/Caches/pip/wheels/cf/81/3b/a50a90282756a5257b8885aeb7d22de09c3bfbf31d66ff455e
#   Building wheel for pandas (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [1049 lines of output]
#       /private/var/folders/0y/r_pk_m1j77vbq82t895ph8780000gq/T/pip-install-il29vzsp/pandas_d8afb4b59b434f78a7687ad1b89c33ca/setup.py:435: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         current_system = LooseVersion(platform.mac_ver()[0])
#       /private/var/folders/0y/r_pk_m1j77vbq82t895ph8780000gq/T/pip-install-il29vzsp/pandas_d8afb4b59b434f78a7687ad1b89c33ca/setup.py:436: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         python_target = LooseVersion(
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-12-arm64-cpython-39
#       creating build/lib.macosx-12-arm64-cpython-39/pandas
#       copying pandas/conftest.py -> build/lib.macosx-12-arm64-cpython-39/pandas
#       copying pandas/_version.py -> build/lib.macosx-12-arm64-cpython-39/pandas
#       copying pandas/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas
#       copying pandas/testing.py -> build/lib.macosx-12-arm64-cpython-39/pandas
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/compat
#       copying pandas/compat/chainmap_impl.py -> build/lib.macosx-12-arm64-cpython-39/pandas/compat
#       copying pandas/compat/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/compat
#       copying pandas/compat/chainmap.py -> build/lib.macosx-12-arm64-cpython-39/pandas/compat
#       copying pandas/compat/pickle_compat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/compat
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/accessor.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/categorical.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/nanops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/missing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/algorithms.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/config.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/resample.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/window.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/index.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/config_init.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/generic.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/series.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/sorting.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/ops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/common.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/frame.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/indexing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/panel.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/base.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/strings.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       copying pandas/core/apply.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/_depr_module.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/_test_decorators.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/_validators.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/_print_versions.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/_decorators.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/_doctools.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/testing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/_exceptions.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       copying pandas/util/_tester.py -> build/lib.macosx-12-arm64-cpython-39/pandas/util
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/feather_format.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/parquet.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/gcs.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/pytables.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/html.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/clipboards.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/parsers.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/excel.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/common.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/date_converters.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/pickle.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/sql.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/s3.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/packers.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/stata.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       copying pandas/io/gbq.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/plotting.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/converter.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/offsets.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/frequencies.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tseries
#       copying pandas/tseries/holiday.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tseries
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_expressions.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_register_accessor.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_common.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_downstream.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_errors.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_sorting.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_join.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_panel.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_lib.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_nanops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_take.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_algos.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_multilevel.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_compat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_config.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_window.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_strings.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       copying pandas/tests/test_base.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/_libs
#       copying pandas/_libs/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/_libs
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/_converter.py -> build/lib.macosx-12-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/_tools.py -> build/lib.macosx-12-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/_style.py -> build/lib.macosx-12-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/_core.py -> build/lib.macosx-12-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/_timeseries.py -> build/lib.macosx-12-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/_compat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/plotting
#       copying pandas/plotting/_misc.py -> build/lib.macosx-12-arm64-cpython-39/pandas/plotting
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/arrays
#       copying pandas/arrays/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/arrays
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/api
#       copying pandas/api/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/api
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/errors
#       copying pandas/errors/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/errors
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/compat/numpy
#       copying pandas/compat/numpy/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/compat/numpy
#       copying pandas/compat/numpy/function.py -> build/lib.macosx-12-arm64-cpython-39/pandas/compat/numpy
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/tile.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/merge.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/concat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/util.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/reshape.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/melt.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       copying pandas/core/reshape/pivot.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/reshape
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/tools
#       copying pandas/core/tools/timedeltas.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/tools
#       copying pandas/core/tools/datetimes.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/tools
#       copying pandas/core/tools/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/tools
#       copying pandas/core/tools/numeric.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/tools
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/util
#       copying pandas/core/util/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/util
#       copying pandas/core/util/hashing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/util
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/cast.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/missing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/concat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/generic.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/dtypes.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/common.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/inference.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       copying pandas/core/dtypes/base.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/dtypes
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/categorical.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/generic.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/ops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/grouper.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/groupby.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/groupby
#       copying pandas/core/groupby/base.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/groupby
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/arrays.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/concat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/construction.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/blocks.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/internals
#       copying pandas/core/internals/managers.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/internals
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/check.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/align.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/pytables.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/engines.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/expressions.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/ops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/common.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/eval.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/scope.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       copying pandas/core/computation/expr.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/computation
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/categorical.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/interval.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/timedeltas.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/datetimes.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/numpy_.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/_ranges.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/integer.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/period.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/sparse.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/datetimelike.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/array_.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       copying pandas/core/arrays/base.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/arrays
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/sparse
#       copying pandas/core/sparse/scipy_sparse.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/sparse
#       copying pandas/core/sparse/series.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/sparse
#       copying pandas/core/sparse/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/sparse
#       copying pandas/core/sparse/api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/sparse
#       copying pandas/core/sparse/frame.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/sparse
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/accessors.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/interval.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/timedeltas.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/range.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/datetimes.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/multi.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/period.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/frozen.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/numeric.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/datetimelike.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/base.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       copying pandas/core/indexes/category.py -> build/lib.macosx-12-arm64-cpython-39/pandas/core/indexes
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/io/msgpack
#       copying pandas/io/msgpack/_version.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/msgpack
#       copying pandas/io/msgpack/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/msgpack
#       copying pandas/io/msgpack/exceptions.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/msgpack
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/console.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/style.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/terminal.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/html.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/format.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/excel.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/css.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/csvs.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/latex.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       copying pandas/io/formats/printing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/io/json
#       copying pandas/io/json/normalize.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/json
#       copying pandas/io/json/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/json
#       copying pandas/io/json/table_schema.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/json
#       copying pandas/io/json/json.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/json
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/sas7bdat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/sas_constants.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/sasreader.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/sas
#       copying pandas/io/sas/sas_xport.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/sas
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/io/clipboard
#       copying pandas/io/clipboard/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/clipboard
#       copying pandas/io/clipboard/clipboards.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/clipboard
#       copying pandas/io/clipboard/exceptions.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/clipboard
#       copying pandas/io/clipboard/windows.py -> build/lib.macosx-12-arm64-cpython-39/pandas/io/clipboard
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_block_internals.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_alter_axes.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_period.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/conftest.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_timeseries.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_constructors.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_missing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_sorting.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_timezones.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_operators.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_subclass.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_analytics.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_io.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_apply.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_quantile.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_datetime_values.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_internals.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/common.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_repr.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_validate.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_duplicates.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_asof.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_rank.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_arithmetic.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_replace.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_combine_concat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       copying pandas/tests/series/test_dtypes.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/series
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_cut.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_union_categoricals.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_qcut.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_reshape.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_util.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_melt.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       copying pandas/tests/reshape/test_concat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/reshape
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/tools
#       copying pandas/tests/tools/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/tools
#       copying pandas/tests/tools/test_numeric.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/tools
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_external_block.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_period.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/conftest.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_common.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_sparse.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_categorical.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_interval.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_datetime.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       copying pandas/tests/extension/test_integer.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/extension
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/conftest.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_resampler_grouper.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_timedelta.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_period_index.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_datetime_index.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_base.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_time_grouper.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       copying pandas/tests/resample/test_resample_api.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/resample
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_validate_args_and_kwargs.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_series_equal.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/conftest.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_safe_import.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_locale.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_frame_equal.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_interval_array_equal.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_util.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_move.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_index_equal.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_validate_args.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_validate_kwargs.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_categorical_equal.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_numpy_array_equal.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_extension_array_equal.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_deprecate.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_hashing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_kwarg.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       copying pandas/tests/util/test_assert_almost_equal.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/util
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_parquet.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_compression.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_date_converters.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/conftest.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_common.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_pickle.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_clipboard.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_stata.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_html.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_pytables.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_gcs.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_sql.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_gbq.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_feather.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/generate_legacy_storage_files.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_excel.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_s3.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       copying pandas/tests/io/test_packers.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/io
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/tseries
#       copying pandas/tests/tseries/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/tseries
#       copying pandas/tests/tseries/test_frequencies.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/tseries
#       copying pandas/tests/tseries/test_holiday.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/tseries
# ...
#       copying pandas/tests/scalar/timestamp/test_arithmetic.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/scalar/timestamp
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/interval
#       copying pandas/tests/indexes/interval/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/interval
#       copying pandas/tests/indexes/interval/test_interval_range.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/interval
#       copying pandas/tests/indexes/interval/test_interval.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/interval
#       copying pandas/tests/indexes/interval/test_astype.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/interval
#       copying pandas/tests/indexes/interval/test_construction.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/interval
#       copying pandas/tests/indexes/interval/test_interval_new.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/interval
#       copying pandas/tests/indexes/interval/test_interval_tree.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/interval
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_names.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/conftest.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_missing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_sorting.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_join.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_copy.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_integrity.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_reshape.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_analytics.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_constructor.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_conversion.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_indexing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_astype.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_equivalence.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_get_set.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_compat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_monotonic.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_drop.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_duplicates.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_set_ops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_contains.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_partial_indexing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_format.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_reindex.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/multi
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_period.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_scalar_compat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_indexing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_astype.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_formats.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_setops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_construction.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_partial_slicing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_ops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_arithmetic.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_tools.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_asfreq.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_period_range.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/period
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_misc.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_missing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_date_range.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_timezones.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_datetimelike.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_scalar_compat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_indexing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_astype.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_formats.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_setops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_datetime.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_construction.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_partial_slicing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_ops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_arithmetic.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_tools.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/datetimes
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_timedelta.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_scalar_compat.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_indexing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_astype.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_formats.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_setops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_construction.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_partial_slicing.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_ops.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_arithmetic.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_timedelta_range.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_tools.py -> build/lib.macosx-12-arm64-cpython-39/pandas/tests/indexes/timedeltas
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/_libs/tslibs
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/api/types
#       copying pandas/api/types/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/api/types
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/api/extensions
#       copying pandas/api/extensions/__init__.py -> build/lib.macosx-12-arm64-cpython-39/pandas/api/extensions
#       creating build/lib.macosx-12-arm64-cpython-39/pandas/io/formats/templates
#       copying pandas/io/formats/templates/html.tpl -> build/lib.macosx-12-arm64-cpython-39/pandas/io/formats/templates
#       UPDATING build/lib.macosx-12-arm64-cpython-39/pandas/_version.py
#       set build/lib.macosx-12-arm64-cpython-39/pandas/_version.py to '0.24.2'
#       running build_ext
#       pandas._libs.algos: -> [['pandas/_libs/algos.c']]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/0y/r_pk_m1j77vbq82t895ph8780000gq/T/pip-install-il29vzsp/pandas_d8afb4b59b434f78a7687ad1b89c33ca/setup.py", line 730, in <module>
#           setup(name=DISTNAME,
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/command/install.py", line 68, in run
#           return orig.install.run(self)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/command/install.py", line 698, in run
#           self.run_command('build')
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#           self.run_command(cmd_name)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/opt/homebrew/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py", line 346, in run
#           self.build_extensions()
#         File "/private/var/folders/0y/r_pk_m1j77vbq82t895ph8780000gq/T/pip-install-il29vzsp/pandas_d8afb4b59b434f78a7687ad1b89c33ca/setup.py", line 372, in build_extensions
#           self.check_cython_extensions(self.extensions)
#         File "/private/var/folders/0y/r_pk_m1j77vbq82t895ph8780000gq/T/pip-install-il29vzsp/pandas_d8afb4b59b434f78a7687ad1b89c33ca/setup.py", line 366, in check_cython_extensions
#           raise Exception("""Cython-generated file '{src}' not found.
#       Exception: Cython-generated file 'pandas/_libs/algos.c' not found.
#                       Cython is required to compile pandas from a development branch.
#                       Please install Cython or download a release package of pandas.
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Rolling back uninstall of pandas
#   Moving to /opt/homebrew/lib/python3.9/site-packages/pandas-1.5.1.dist-info/
#    from /opt/homebrew/lib/python3.9/site-packages/~andas-1.5.1.dist-info
#   Moving to /opt/homebrew/lib/python3.9/site-packages/pandas/
#    from /opt/homebrew/lib/python3.9/site-packages/~andas
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pandas
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 get_ipython().system('pip install google.colab')
# ----> 2 from google.colab import drive
#       3 drive.mount('/content/gdrive/', force_remount=True)
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# Optional: If you experience any issues and want to verify that the notebook can access your Google Drive file system, execute the following code. It should display a list of files located in your Google Drive.

# %%
# %ls gdrive/MyDrive

# %% [markdown]
# Create a folder in Google Drive to store the configuration, osom-data, and results files.

# %%
# %mkdir ./gdrive/MyDrive/osom3d/
# %mkdir ./gdrive/MyDrive/osom3d/grid-data/
# %mkdir ./gdrive/MyDrive/osom3d/configurations/
# %mkdir ./gdrive/MyDrive/osom3d/osom-data/
# %mkdir ./gdrive/MyDrive/osom3d/results/

# %% [markdown]
# ## 3. Download Grid File
#
# Now, we need to download the nc grid file to map our global data points to the application coordinates. Execute the following command.

# %%
! wget -P ./gdrive/MyDrive/osom3d/grid-data/ https://github.com/brown-ccv/volume-data-converter/raw/main/volume_data_converter/resources/grid-data/osom_grid4_mindep_smlp_mod7-netcdf4.nc

# %% [markdown]
# ## 4. Install Volume Converter package
#
# We have to install the `volume_data_converter` library that converts the OSOM nc files to Volume Viewer data

# %%
! pip install volume-data-converter@git+https://github.com/brown-ccv/volume-data-converter.git@v2.2.2

# %% [markdown]
# ## 4. Download OSOM data from ERDDAP
#
# First we need to acquire data from the ERDDAP server. In order to configure a connection and set up constrains for your search, create a json containing the connection url, protocol type and dataset id. You can also specify a time range and coordinates. The following is an example on how to create a json file with the mentioned properties.
# The command will create a file in your virtual local folder. We will use the result output in the next step.

# %%
import json 
dictionary ={ 
  "erddap_connection": {"server": "https://pricaimcit.services.brown.edu/erddap","protocol": "griddap","dataset_id": "model_data_57db_4a85_81d9"}, 
  "erddap_constrainsts": {"variables":["SalinityBottom","SalinitySurface"],  "time>=": "2019-12-30T00:00:00Z",
        "time<=": "2019-12-31T00:00:00Z",
        "time_step": 1,
        "eta_rho>=": 0,
        "eta_rho<=": 1099,
        "eta_rho_step": 1,
        "xi_rho>=": 0,
        "xi_rho<=": 999,
        "xi_rho_step": 1
        }, 
} 

with open('./gdrive/MyDrive/osom3d/configurations/erddap_connection.json', 'w') as f:
    json_object = json.dumps(dictionary, indent = 4) 
    f.write(json_object)

# %% [markdown]
# After running the previous script, if we list the files in our Google Drive folder, we can see the recently created `'erddap_connection.json'` file.

# %%
# %ls ./gdrive/MyDrive/osom3d/configurations

# %% [markdown]
# Using the `volume_data_converter` library, we will pass `erddap_connection.json` to the `my_erddap_query` function to start the download process and retrieve the data from ERDDAP.

# %%
from volume_data_converter.erddap_query import erddap_query as my_erddap_query
my_erddap_query("./gdrive/MyDrive/osom3d/osom-data/","./gdrive/MyDrive/osom3d/configurations/erddap_connection.json")

# %% [markdown]
# If we list the files in our Google Drive folder, we can see the ouput file `model_data_57db_4a85_81d9.nc` which is the name of the dataset id specified in the `erddap_connection.json`.

# %%
# %ls ./gdrive/MyDrive/osom3d/osom-data
# Out:
# model_data_57db_4a85_81d9.nc

# %% [markdown]
# ## 5. Convert NC-OSOM data file to Volume Viewer file format
#
# Now we will create another json file containing the configuration to convert the nc file to raw data that the Volume Viewer app will read. The following code is an example of the type of configuration file the `volume_data_converter` expects to work with:
#
# - `osom_grid_file`: Path to the nc grid file (the first downloaded file)
# - `osom_data_file`: Path to the OSOM nc data file (`model_data_57db_4a85_81d9.nc`)
# - `ouput_folder`: Path where the resulting package will be saved (a place in your Google Drive file system)
# - `data_descriptor`: The OSOM variable to export to the Volume Viewer (e.g., temperature, salt)
# - `time_frames`: If the dataset has multiple time frames, it will export all of them (time sequence). Otherwise, specify the required frame. (i.e: Null, [0,1],[5,6,7])
# - `layer`: OSOM-supported files have 3 different types of layers: `all`(default), `surface`, `bottom`.
# - `to_texture_atlas`:  Flag to convert the volume viewer dataset to a texture atlas image (jpg) or 3D matrix strucure (.raw): `True` or `False` (default).
#
# ### IMPORTANT:
# MacOS users must set the `to_texture_atlas` flag to `True`. Windows and Linux systems support both (jpg and raw) modes.
#
# The following code will create the `volume_viewer_data.json` file with the given configuration.

# %%
import json 
dictionary ={ 
  "osom_grid_file": "./gdrive/MyDrive/osom3d/grid-data/osom_grid4_mindep_smlp_mod7-netcdf4.nc",
  "osom_data_file": "./gdrive/MyDrive/osom3d/osom-data/model_data_57db_4a85_81d9.nc",
  "output_folder": "./gdrive/MyDrive/osom3d/results/",
  "data_descriptor" : "SalinityBottom",
  "time_frames": [0],
  "layer" : "bottom",
  "to_texture_atlas": False
} 

with open('./gdrive/MyDrive/osom3d/configurations/volume_viewer_data.json', 'w') as f:
    json_object = json.dumps(dictionary, indent = 4) 
    f.write(json_object)

# %% [markdown]
#  Finally, we import the `create_osom_data` script and pass the `volume_viewer_data.json` file to start the conversion process.

# %%
from volume_data_converter.create_volume_viewer_data import create_osom_data as my_create_volume_viewer_data
my_create_volume_viewer_data("./gdrive/MyDrive/osom3d/configurations/volume_viewer_data.json")

# %% [markdown]
# Take into account that the defined ouput file path points to `./gdrive/myDrive/osom`. That is a location inside **your** Google Drive. From there you can download to the environment in which you are running the Volume Viewer application.

# %%
# %ls ./gdrive/MyDrive/osom3d/results/osom-data-SalinityBottom
# Out:
# data/  labels/  osom-loader.txt  textures/

# %% [markdown]
# ## 6. Load data into the Volume Viewer
#
#
# - Go to your Google Drive web app. If you are working on Oscar, first load the Google Chrome module and open a chrome browser to access your Google Drive. Open a new terminal tab and type the following to get a Chrome browser:
#
# `module load chrome`
# `google-chrome --no-sandbox`
#
# When the browser opens, sign in to Google and navigate to your Google Drive. In the left side panel you will find the result output folder (see image below). Right-click on the folder and select **Download**.
#
# ![google drive folder](https://raw.githubusercontent.com/ridatadiscoverycenter/riddc-jbook/main/riddc/notebooks/fox-kemper/images/Screen%20Shot%20google%20drive%20file%20system.png)
#
#
# - Unzip the osom3d file and navigate to the open Volume Viewer application.
#
# - If you are on Oscar, make sure the osom3d folder gets extracted to `/gpfs/home/<username>/Downloads/osom3d`
#
# - Click on `load file` and navigate to `/gpfs/home/<username>/Downloads/osom3d/results/osom-data-SalinityBottom`. Double click the `osom-loader.txt` file.
#
# ![volume viewer clip](https://raw.githubusercontent.com/ridatadiscoverycenter/riddc-jbook/main/riddc/notebooks/fox-kemper/images/clip-volume-viewer.gif)
#
#
# - After a few seconds, the volume will be loaded.
#
# ![volume viewer loaded](https://raw.githubusercontent.com/ridatadiscoverycenter/riddc-jbook/main/riddc/notebooks/fox-kemper/images/volume-viewer-4.png)
#
# - Check the box next to TF1 to turn on the transfer function and have fun playing around with the Volume Viewer!
#
# ![transfer function clip](https://raw.githubusercontent.com/ridatadiscoverycenter/riddc-jbook/main/riddc/notebooks/fox-kemper/images/transfer_function_example.png)
#
# - For any support or questions with this product, please reach out to The Center for Computation and Visualization via any of the mediums listed [on our help page](https://ccv.brown.edu/help)
# * Email us at support@ccv.brown.edu
