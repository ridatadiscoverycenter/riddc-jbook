# %% [markdown]
# ***We recommend working this notebook on Google colab***
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ridatadiscoverycenter/riddc-jbook/blob/feature-volume-converter/riddc/notebooks/fox-kemper/volume_viewer_converter.ipynb)
#
# ## VISUALIZE OSOM DATA USING THE VOLUMEN VIEWER
#
# We have created the following example on how to export osom datasets and visualize them in 3D using the volume viewer application.
# These scripts create large amount of data, and we recommend to use your google drive to save them. All the instructions here explains how to proceed.
#
# First, let's connect to our google drive. Execute the command below
#
# **NOTE: The following command will open a pop-up window requesting access to your google drive file system**

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Optional: The previous code works most of the times. If you experience any issues and want to verify the book can see your google drive file system, execute the following code. It should display a list of files located in your google drive.

# %%
# %ls gdrive/MyDrive
# Out:
# ls: cannot access 'gdrive/MyDrive': No such file or directory

# %% [markdown]
# Now, we need to download the nc grid file to map our global data points to the application coordinates. Execue the following command.

# %%
# !wget https://github.com/brown-ccv/volume-data-converter/raw/main/volume_data_converter/resources/grid-data/osom_grid4_mindep_smlp_mod7-netcdf4.nc
# Out:
# --2022-11-14 21:24:08--  https://github.com/brown-ccv/volume-data-converter/raw/main/volume_data_converter/resources/grid-data/osom_grid4_mindep_smlp_mod7-netcdf4.nc
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/brown-ccv/volume-data-converter/main/volume_data_converter/resources/grid-data/osom_grid4_mindep_smlp_mod7-netcdf4.nc [following]
# --2022-11-14 21:24:08--  https://media.githubusercontent.com/media/brown-ccv/volume-data-converter/main/volume_data_converter/resources/grid-data/osom_grid4_mindep_smlp_mod7-netcdf4.nc
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 237463021 (226M) [application/octet-stream]
# Saving to: ‘osom_grid4_mindep_smlp_mod7-netcdf4.nc’
#
# osom_grid4_mindep_s 100%[===================>] 226.46M   226MB/s    in 1.0s
#
# 2022-11-14 21:24:16 (226 MB/s) - ‘osom_grid4_mindep_smlp_mod7-netcdf4.nc’ saved [237463021/237463021]

# %% [markdown]
# We have to install the `volume_data_converter` library that converts the osom nc files to volume viewer data

# %%
! pip install volume-data-converter@git+https://github.com/brown-ccv/volume-data-converter.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git
#   Cloning https://github.com/brown-ccv/volume-data-converter.git to /tmp/pip-install-glf57mj7/volume-data-converter_72c780e6c88f4e1cbae4a5a93c7dca30
#   Running command git clone -q https://github.com/brown-ccv/volume-data-converter.git /tmp/pip-install-glf57mj7/volume-data-converter_72c780e6c88f4e1cbae4a5a93c7dca30
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting netCDF4==1.5.7
#   Downloading netCDF4-1.5.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 5.1 MB/s
# Collecting matplotlib<4.0.0,>=3.5.1
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 45.2 MB/s
# Collecting pypng<0.20220716.0,>=0.20220715.0
#   Downloading pypng-0.20220715.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.3 MB/s
# Collecting erddapy<2.0.0,>=1.2.1
#   Downloading erddapy-1.2.1-py3-none-any.whl (18 kB)
# Collecting numpy==1.21.2
#   Downloading numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 4.1 MB/s
# Collecting pyseq<0.6.0,>=0.5.5
#   Downloading pyseq-0.5.5.tar.gz (12 kB)
# Requirement already satisfied: imagesize<2.0.0,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (1.4.1)
# Collecting Pillow<10.0.0,>=9.2.0
#   Downloading Pillow-9.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 44.8 MB/s
# Collecting imageio<3.0.0,>=2.21.1
#   Downloading imageio-2.22.4-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 37.5 MB/s
# Requirement already satisfied: typer<0.5.0,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (0.4.2)
# Collecting halo<0.0.32,>=0.0.31
#   Downloading halo-0.0.31.tar.gz (11 kB)
# Collecting tiffile<2019.0.0,>=2018.10.18
#   Downloading tiffile-2018.10.18-py2.py3-none-any.whl (2.7 kB)
# Collecting opencv-contrib-python==4.5.4.60
#   Downloading opencv_contrib_python-4.5.4.60-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (66.5 MB)
#      |████████████████████████████████| 66.5 MB 103 kB/s
# Collecting mplhep<0.4.0,>=0.3.26
#   Downloading mplhep-0.3.26-py3-none-any.whl (34 kB)
# Requirement already satisfied: scipy==1.7.3 in /usr/local/lib/python3.7/dist-packages (from volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (1.7.3)
# Requirement already satisfied: importlib-resources<6.0.0,>=5.9.0 in /usr/local/lib/python3.7/dist-packages (from volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (5.10.0)
# Requirement already satisfied: cftime<2.0.0,>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (1.6.2)
# Collecting xarray==0.20.0
#   Downloading xarray-0.20.0-py3-none-any.whl (835 kB)
#      |████████████████████████████████| 835 kB 47.6 MB/s
# Requirement already satisfied: typing-extensions>=3.7 in /usr/local/lib/python3.7/dist-packages (from xarray==0.20.0->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (4.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from xarray==0.20.0->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (4.13.0)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from xarray==0.20.0->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (1.3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from erddapy<2.0.0,>=1.2.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (2.23.0)
# Collecting log_symbols>=0.0.14
#   Downloading log_symbols-0.0.14-py3-none-any.whl (3.1 kB)
# Collecting spinners>=0.0.24
#   Downloading spinners-0.0.24-py3-none-any.whl (5.5 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from halo<0.0.32,>=0.0.31->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (2.1.0)
# Collecting colorama>=0.3.9
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from halo<0.0.32,>=0.0.31->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources<6.0.0,>=5.9.0->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 61.2 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (0.11.0)
# Collecting uhi>=0.2.0
#   Downloading uhi-0.3.2-py3-none-any.whl (10 kB)
# Collecting mplhep-data
#   Downloading mplhep_data-0.0.3-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 3.5 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->xarray==0.20.0->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (2022.6)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.7/dist-packages (from tiffile<2019.0.0,>=2018.10.18->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (2021.11.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.4.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (7.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->erddapy<2.0.0,>=1.2.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->erddapy<2.0.0,>=1.2.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->erddapy<2.0.0,>=1.2.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->erddapy<2.0.0,>=1.2.1->volume-data-converter@ git+https://github.com/brown-ccv/volume-data-converter.git) (3.0.4)
# Building wheels for collected packages: volume-data-converter, halo, pyseq
#   Building wheel for volume-data-converter (PEP 517) ... done
#   Created wheel for volume-data-converter: filename=volume_data_converter-0.1.0-py3-none-any.whl size=41761418 sha256=e3ac3626634be831af7105559373d6e14152b55fcaeed1e9cd61a1095e22e6d2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mn9owqhj/wheels/59/03/fd/8ff8803a99fb602ef9c006e430f46138808bbc29bdad40f04b
#   Building wheel for halo (setup.py) ... done
#   Created wheel for halo: filename=halo-0.0.31-py3-none-any.whl size=11262 sha256=6f4ee7dd502a9ee17df306424ff869f01525636b972d21cc012b3b56125624ef
#   Stored in directory: /root/.cache/pip/wheels/95/ff/20/5d16a0059f20c5e60be2df845201e73af179a5a79a3d566f48
#   Building wheel for pyseq (setup.py) ... done
#   Created wheel for pyseq: filename=pyseq-0.5.5-py3-none-any.whl size=14058 sha256=f6bccea1243b74334c00ca3c00fd4a706278b79024f14b0d1f0e28c9e03e3717
#   Stored in directory: /root/.cache/pip/wheels/28/3d/cf/3e4393867b9963bf87eb385addcd9feb2229bce23f94a9aaa2
# Successfully built volume-data-converter halo pyseq
# Installing collected packages: Pillow, numpy, fonttools, colorama, uhi, spinners, mplhep-data, matplotlib, log-symbols, xarray, tiffile, pyseq, pypng, opencv-contrib-python, netCDF4, mplhep, imageio, halo, erddapy, volume-data-converter
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: xarray
#     Found existing installation: xarray 0.20.2
#     Uninstalling xarray-0.20.2:
#       Successfully uninstalled xarray-0.20.2
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.6.0.66
#     Uninstalling opencv-contrib-python-4.6.0.66:
#       Successfully uninstalled opencv-contrib-python-4.6.0.66
#   Attempting uninstall: netCDF4
#     Found existing installation: netCDF4 1.6.1
#     Uninstalling netCDF4-1.6.1:
#       Successfully uninstalled netCDF4-1.6.1
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.9.0
#     Uninstalling imageio-2.9.0:
#       Successfully uninstalled imageio-2.9.0
# Successfully installed Pillow-9.3.0 colorama-0.4.6 erddapy-1.2.1 fonttools-4.38.0 halo-0.0.31 imageio-2.22.4 log-symbols-0.0.14 matplotlib-3.5.3 mplhep-0.3.26 mplhep-data-0.0.3 netCDF4-1.5.7 numpy-1.21.2 opencv-contrib-python-4.5.4.60 pypng-0.20220715.0 pyseq-0.5.5 spinners-0.0.24 tiffile-2018.10.18 uhi-0.3.2 volume-data-converter-0.1.0 xarray-0.20.0

# %% [markdown]
# First we need to acquire data from the erddap server. In order to configure a connection and set up constrains for your search, create a json containing the connection url, protocol type and dataset id. You can also specify a time range and coordinates. The following is an example on how to create a json file with the mentioned properties.
# The command will create a file in your virtual local folder. We will use the result output in the next step.

# %%
import json 
dictionary ={ 
  "erddap_connection": {"server": "https://pricaimcit.services.brown.edu/erddap","protocol": "griddap","dataset_id": "model_data_57db_4a85_81d9"}, 
  "erddap_constrainsts": {"variables":["SalinityBottom","SalinitySurface"],  "time>=": "2019-12-30T00:00:00Z",
        "time<=": "2019-12-31T00:00:00Z",
        "time_step": 1,
        "eta_rho>=": 0,
        "eta_rho<=": 1099,
        "eta_rho_step": 1,
        "xi_rho>=": 0,
        "xi_rho<=": 999,
        "xi_rho_step": 1
        }, 
} 

with open('erddap_connection.json', 'w') as f:
    json_object = json.dumps(dictionary, indent = 4) 
    f.write(json_object)

# %% [markdown]
# After running the previous script, if we list the files in our local virtual folder, we can see the recently created `'erddap_connection.json'` file.

# %%
# %ls
# Out:
# erddap_connection.json  osom_grid4_mindep_smlp_mod7-netcdf4.nc
# gdrive/                 sample_data/

# %% [markdown]
# Using the `volume_data_converter` library, we will pass `erddap_connection.json` to the `my_erddap_query` function to start up the to download process and retrieve the data from erddap.

# %%
from volume_data_converter.erddap_query import erddap_query as my_erddap_query
my_erddap_query("./","erddap_connection.json")
# Out:
# Ouput folder path is a directory. File-name auto assigned to: model_data_57db_4a85_81d9.nc
# Connecting to server: https://pricaimcit.services.brown.edu/erddap
# Looking up dataset id : model_data_57db_4a85_81d9
# Retrieving data from server. Please be patient, it may take a while.
# Data downloaded to file ./model_data_57db_4a85_81d9.nc

# %% [markdown]
# If we list the files in our local virtual folder, we can see the ouput file `model_data_57db_4a85_81d9.nc` which is the name of the dataset id pointent in the `erddap_connection.json`.

# %%
# %ls
# Out:
# erddap_connection.json        osom_grid4_mindep_smlp_mod7-netcdf4.nc
# gdrive/                       sample_data/
# model_data_57db_4a85_81d9.nc  volume_viewer_data.json

# %% [markdown]
# Now we will create another json file containing the configuration to convert the nc file to raw data that the volume viewer app will read. The following code is an example of the type of configuration file the `volume_data_converter`expects to work with:
#
# - `osom_grid_file`: Path to the nc grid file (the first downloaded file)
# - `osom_data_file`: Path to the nc osom data file (`model_data_57db_4a85_81d9.nc`)
# - `ouput_folder`: Path where the resulting package will be saved (a place in your google drive file system)
# - `data_descriptor`: The osom variable to export to the voluem viewer (temp,salt)
# - `time_frames`: If the dataset has multiple time frames, it will export all of them (time sequence). Otherwise, specify the required frame. (i.e: Null, [0,1],[5,6,7])
# - `layer`: Currently osom supported files have 3 different types of layes `all`(default), `surface`, `bottom`.
#
# The following code will create the `volume_viewer_data.json` file with the given configuration.

# %%
import json 
dictionary ={ 
  "osom_grid_file": "./gdrive/MyDrive/osom_grid4_mindep_smlp_mod7-netcdf4.nc",
  "osom_data_file": "./model_data_57db_4a85_81d9.nc",
  "output_folder": "./gdrive/MyDrive/osom",
  "data_descriptor" : "SalinityBottom",
  "time_frames": [0],
  "layer" : "bottom"
} 

with open('volume_viewer_data.json', 'w') as f:
    json_object = json.dumps(dictionary, indent = 4) 
    f.write(json_object)

# %% [markdown]
#  Finally, we import the `create_osom_data` script and pass the `volume_viewer_data.json` file to start up the conversion process.

# %%
from volume_data_converter.create_volume_viewer_data import create_osom_data as my_create_volume_viewer_data
my_create_volume_viewer_data("./volume_viewer_data.json")
# Out:
#  Reading ./gdrive/MyDrive/osom_grid4_mindep_smlp_mod7-netcdf4.nc
#  Reading ./model_data_57db_4a85_81d9.nc
#  Assigning data from data files
#  Computing ROMS vertical stretched coordinates
#
#  Converting nc data to raw and desc files. This process will take time
#  Creating volume viewer package
#  End of process

# %% [markdown]
# Take in count the defined ouput file path points to `./gdrive/myDrive/osom`. That is a location inside **your** google drive. From there you can downloaded to the environment you are running the volume viewer application

# %%
# %ls ./gdrive/MyDrive/osom
# Out:
# osom-data-SalinityBottom/
